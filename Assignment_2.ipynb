# %%
#Q1(1)
lst=['Smita', 'Vedant', 'Yashraj','Viraj', 'Priyanka']
lst1=['Porsche','Volvo','Range Rover','Porsche']

lst_1=lst.append('Swift02')
print(lst_1,lst)

lst_2=lst.extend(lst1)
print(lst_2,lst)

lst_3=lst1.insert(2,'Iphone')
print(lst_3,lst1)

lst_4=lst1.remove('Iphone')
print(lst_4,lst1)

print(lst1.pop(2))

lst1.clear()
print(lst1)

print(lst.index('Viraj'))

print(lst1.count('Porsche'))

lst1.sort()
print(lst1)

lst.reverse()
print(lst)

#Q1(2)
students=("Swaraj", "Khali", "Rakesh")
students[1]="Priya"
#Tupples are irreplaceble , it gives error


#Q1(3)
integer={"2","3","8","7","3","4","2"}
print(integer)
""" Set doesnot see repeated values, order is unpredictable, keep only unique elements"""

#Q1(4)
person={
        "name" : "Vedant",
        "age" : 20,
        "City" : "Pune"
        }

person["age"]=21

person["email"]="vedant.thokal22@vit.edu"

print(person)

for key, value in person.items():
    print(key, ":" , value)
    
    
#Q1(5)
age=int(input("Enter Your Age :"))

print("\n-----ELECTION COMISSION OF INDIA-----")
if age>=18:
    print("YOU ARE ELIGIBLE TO VOTE !")
    
else:
    print("YOU ARE NOT ELIGIBLE TO VOTE !")
    
#Q1(6)
marks=int(input("Enter your marks :"))

if marks>=90:
    print("GRADE A")
    
elif 90>marks>=75:
    print("GRADE B")
    
elif 75>marks>=50:
    print("GRADE C")
    
else:
    print("FAIL !")
    
#Q1(7)
num=int(input("Enter the number :"))

if num>0:
    print("The number is Positive")
    
    if num%2==0:
        print("The number is also EVEN !")
    
    else:
        print("The number is also ODD !")
        
elif num==0:
    print("The number is ZERO !")
    
else:
    print("The number is NEGATIVE !")
    
 
 
#Q2(1)
import numpy as np

scalar=np.array(5)
print("Scalar :",scalar)

one_d=np.array([1,2,3,4,5])
print("1D Array :",one_d)

two_d=np.array([[10,20,30],
                [40,50,60]])
print("\n2D Array :",two_d)

#Q2(2)
import numpy as np

arr=np.random.randint(0,101,size=(4,4))
print(arr)

#Q2(3)
import numpy as np

two_d=np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90]
    ])
print("2D Array :",two_d)

import pandas as pd

df=pd.DataFrame(two_d)
df

df=pd.DataFrame(two_d,index=['Row1','Row2','Row3'],columns=['Column A','Column B','Column C'])
print(df)

#Q3
import pandas as pd
import numpy as np

data = {
    'Name': ['Amit', 'Neha', 'Ravi', 'Priya', 'Amit',
             'Kiran', 'Sneha', 'Rahul', 'Neha', 'Arjun'],
    'Age': [22, 25, 23, 24, 22,
            26, 27, 28, 25, 29],
    'City': ['Pune', 'Mumbai', 'Delhi', 'Pune', 'Pune',
             'Mumbai', 'Delhi', 'Pune', 'Mumbai', 'Delhi'],
    'Salary': [50000, 60000, np.nan, 55000, 50000,
               65000, np.nan, 70000, 60000, 75000]
}

df = pd.DataFrame(data)

print("Original DataFrame:\n")
print(df)

df.info()

df.describe()

df[['Name', 'City']]

mean_salary = df['Salary'].mean()
df['Salary'].fillna(mean_salary, inplace=True)
print(df)

df.drop_duplicates(inplace=True)
print(df)
# Out:
# None ['Smita', 'Vedant', 'Yashraj', 'Viraj', 'Priyanka', 'Swift02']
# None ['Smita', 'Vedant', 'Yashraj', 'Viraj', 'Priyanka', 'Swift02', 'Porsche', 'Volvo', 'Range Rover', 'Porsche']
# None ['Porsche', 'Volvo', 'Iphone', 'Range Rover', 'Porsche']
# None ['Porsche', 'Volvo', 'Range Rover', 'Porsche']
# Range Rover
# []
# 3
# 0
# []
# ['Porsche', 'Range Rover', 'Volvo', 'Porsche', 'Swift02', 'Priyanka', 'Viraj', 'Yashraj', 'Vedant', 'Smita']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 34
#      32 #Q1(2)
#      33 students=("Swaraj", "Khali", "Rakesh")
# ---> 34 students[1]="Priya"
#      35 #Tupples are irreplaceble , it gives error
#      36
#      37
#      38 #Q1(3)
#      39 integer={"2","3","8","7","3","4","2"}
#
# TypeError: 'tuple' object does not support item assignment
